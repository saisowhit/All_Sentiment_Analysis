# %%
# ## sentiment analysis using Pytho using
# 1. VADER
# 2. Roberta Pretained Model
# 3. Huggingface Pipeline

# %%
# !pip3 install svgling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 9.1 MB/s eta 0:00:00
# ...

# %%
# !pip3 install nltk
import nltk
import warnings
nltk.download('maxent_ne_chunker_tab')
import nltk
nltk.download('averaged_perceptron_tagger_eng')
import nltk
nltk.download('punkt_tab')
import nltk
nltk.download('words')
warnings.filterwarnings("ignore")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 60.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.7/782.7 kB 62.6 MB/s eta 0:00:00
# ...
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package words to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import nltk
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df=pd.read_csv("Final_Reviews.csv")

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
ax=df['Score'].value_counts().sort_index().plot(kind="bar")
ax.set_xlabel("Review stars")
plt.show()

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
example=df['Text']
example=str(example)
print(example)
# Out:
# 0      I have bought several of the Vitality canned d...
# 1      Product arrived labeled as Jumbo Salted Peanut...
# 2      This is a confection that has been around a fe...
# 3      If you are looking for the secret ingredient i...
# 4      Great taffy at a great price.  There was a wid...
#                              ...
# 376    Oh my gosh, is this good!  Like most people, I...
# 377    Sir Kensington's did a great job of updating t...
# 378    This is ridiculous.  The best gourmet ketchup ...
# 379    The tomatoes are the star of the classic flavo...
# 380    The spicy version of this ketchup isn't bad, b...
# Name: Text, Length: 381, dtype: object

# %%
tokens=nltk.word_tokenize(example)
tokens
# Out:
# ['0',
#  'I',
#  'have',
#  'bought',
#  'several',
#  'of',
#  'the',
#  'Vitality',
#  'canned',
#  'd',
#  '...',
#  '1',
#  'Product',
#  'arrived',
#  'labeled',
#  'as',
#  'Jumbo',
#  'Salted',
#  'Peanut',
#  '...',
#  '2',
#  'This',
#  'is',
#  'a',
#  'confection',
#  'that',
#  'has',
#  'been',
#  'around',
#  'a',
#  'fe',
#  '...',
#  '3',
#  'If',
#  'you',
#  'are',
#  'looking',
#  'for',
#  'the',
#  'secret',
#  'ingredient',
#  'i',
#  '...',
#  '4',
#  'Great',
#  'taffy',
#  'at',
#  'a',
#  'great',
#  'price',
#  '.',
#  'There',
#  'was',
#  'a',
#  'wid',
#  '...',
#  '...',
#  '376',
#  'Oh',
#  'my',
#  'gosh',
#  ',',
#  'is',
#  'this',
#  'good',
#  '!',
#  'Like',
#  'most',
#  'people',
#  ',',
#  'I',
#  '...',
#  '377',
#  'Sir',
#  'Kensington',
#  "'s",
#  'did',
#  'a',
#  'great',
#  'job',
#  'of',
#  'updating',
#  't',
#  '...',
#  '378',
#  'This',
#  'is',
#  'ridiculous',
#  '.',
#  'The',
#  'best',
#  'gourmet',
#  'ketchup',
#  '...',
# ...

# %%
tagged=nltk.pos_tag(tokens)
print(tagged)
# Out:
# [('0', 'CD'), ('I', 'PRP'), ('have', 'VBP'), ('bought', 'VBN'), ('several', 'JJ'), ('of', 'IN'), ('the', 'DT'), ('Vitality', 'NNP'), ('canned', 'VBD'), ('d', 'NN'), ('...', ':'), ('1', 'CD'), ('Product', 'NNP'), ('arrived', 'VBD'), ('labeled', 'VBN'), ('as', 'IN'), ('Jumbo', 'NNP'), ('Salted', 'NNP'), ('Peanut', 'NNP'), ('...', ':'), ('2', 'CD'), ('This', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('confection', 'NN'), ('that', 'WDT'), ('has', 'VBZ'), ('been', 'VBN'), ('around', 'IN'), ('a', 'DT'), ('fe', 'NN'), ('...', ':'), ('3', 'CD'), ('If', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('looking', 'VBG'), ('for', 'IN'), ('the', 'DT'), ('secret', 'JJ'), ('ingredient', 'NN'), ('i', 'NN'), ('...', ':'), ('4', 'CD'), ('Great', 'NNP'), ('taffy', 'NN'), ('at', 'IN'), ('a', 'DT'), ('great', 'JJ'), ('price', 'NN'), ('.', '.'), ('There', 'EX'), ('was', 'VBD'), ('a', 'DT'), ('wid', 'NN'), ('...', ':'), ('...', ':'), ('376', 'CD'), ('Oh', 'NNP'), ('my', 'PRP$'), ('gosh', 'NN'), (',', ','), ('is', 'VBZ'),
# ...

# %%
# tokens

# %%
entites=nltk.chunk.ne_chunk(tagged)
entites.pprint()
# Out:
# (S
#   0/CD
#   I/PRP
#   have/VBP
#   bought/VBN
#   several/JJ
#   of/IN
#   the/DT
#   (ORGANIZATION Vitality/NNP)
#   canned/VBD
#   d/NN
#   .../:
#   1/CD
#   Product/NNP
#   arrived/VBD
#   labeled/VBN
#   as/IN
#   (PERSON Jumbo/NNP Salted/NNP Peanut/NNP)
#   .../:
#   2/CD
#   This/DT
#   is/VBZ
#   a/DT
#   confection/NN
#   that/WDT
#   has/VBZ
#   been/VBN
#   around/IN
#   a/DT
#   fe/NN
#   .../:
#   3/CD
#   If/IN
#   you/PRP
#   are/VBP
#   looking/VBG
#   for/IN
#   the/DT
#   secret/JJ
#   ingredient/NN
#   i/NN
#   .../:
#   4/CD
#   (GPE Great/NNP)
#   taffy/NN
#   at/IN
#   a/DT
#   great/JJ
#   price/NN
#   ./.
#   There/EX
#   was/VBD
#   a/DT
#   wid/NN
#   .../:
#   .../:
#   376/CD
#   Oh/NNP
#   my/PRP$
#   gosh/NN
#   ,/,
#   is/VBZ
#   this/DT
#   good/JJ
#   !/.
#   Like/IN
#   most/JJS
#   people/NNS
#   ,/,
#   I/PRP
#   .../:
#   377/CD
#   Sir/NNP
#   (PERSON Kensington/NNP)
#   's/POS
#   did/VBD
#   a/DT
#   great/JJ
#   job/NN
#   of/IN
# ...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
## Step: 1 Vader

# %%
# This uses a bag of words approach
## stop words are removed
# Each word is scored and combined to a total score

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

# %%
sia=SentimentIntensityAnalyzer()
sia.polarity_scores('I am happy')
# Out:
# {'neg': 0.0, 'neu': 0.213, 'pos': 0.787, 'compound': 0.5719}

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/ec2-user/nltk_data...
# True

# %%
df.head(1)
# Out:
#    Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian                     1
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...

# %%
## Roberta Pretrained Model

# %%
len(df)
# Out:
# 381

# %%
res={}
for i,row in  tqdm(df.iterrows(),total=len(df)): 
    text=row['Text']
    myid=row['Id']
    res[myid]=sia.polarity_scores(text)
# Out:
#   0%|          | 0/381 [00:00<?, ?it/s]

# %%
res
# Out:
# {1: {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.9441},
#  2: {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.5664},
#  3: {'neg': 0.091, 'neu': 0.754, 'pos': 0.155, 'compound': 0.8265},
#  4: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  5: {'neg': 0.0, 'neu': 0.552, 'pos': 0.448, 'compound': 0.9468},
#  6: {'neg': 0.029, 'neu': 0.809, 'pos': 0.163, 'compound': 0.883},
#  7: {'neg': 0.034, 'neu': 0.693, 'pos': 0.273, 'compound': 0.9346},
#  8: {'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.9487},
#  9: {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.6369},
#  10: {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.8313},
#  11: {'neg': 0.017, 'neu': 0.846, 'pos': 0.137, 'compound': 0.9746},
#  12: {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'compound': -0.7579},
#  13: {'neg': 0.031, 'neu': 0.923, 'pos': 0.046, 'compound': 0.296},
#  14: {'neg': 0.0, 'neu': 0.355, 'pos': 0.645, 'compound': 0.9466},
# ...

# %%
vaders=pd.DataFrame(res).T

# %%
vaders
# Out:
#        neg    neu    pos  compound
# 1    0.000  0.695  0.305    0.9441
# 2    0.138  0.862  0.000   -0.5664
# 3    0.091  0.754  0.155    0.8265
# 4    0.000  1.000  0.000    0.0000
# 5    0.000  0.552  0.448    0.9468
# ..     ...    ...    ...       ...
# 377  0.000  0.796  0.204    0.8740
# 378  0.046  0.793  0.161    0.9341
# 379  0.063  0.524  0.413    0.9709
# 380  0.036  0.695  0.269    0.9468
# 381  0.074  0.715  0.212    0.8349
#
# [381 rows x 4 columns]

# %%
vaders=vaders.reset_index().rename(columns={'index':'Id'})
vaders.dtypes
vaders_one=vaders.merge(df,how="left", on='Id')
# # vaders

# %%
## plotting vader

# %%
ax=sns.barplot(data=vaders_one,x='Score',y='compound')
ax.set_title('Compound score by Amazon star review')
plt.show()

# %%
fig,axs=plt.subplots(1, 3, figsize=(12,3))
sns.barplot(data=vaders_one,x='Score',y='pos',ax=axs[0])
sns.barplot(data=vaders_one,x='Score',y='neg',ax=axs[1])
sns.barplot(data=vaders_one,x='Score',y='neu',ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Negative')
axs[2].set_title('Neutral')
plt.show()

# %%
## Roberta Pretrained Model

# %%
# !pip3 install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 99.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 44.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.0/435.0 kB 52.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 101.6 MB/s eta 0:00:0000:01
# ...

# %%
from transformers import AutoTokenizer,AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL=f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer=AutoTokenizer.from_pretrained(MODEL)
model=AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
print(example)
sia.polarity_score(example)
# Out:
# 0      I have bought several of the Vitality canned d...
# 1      Product arrived labeled as Jumbo Salted Peanut...
# 2      This is a confection that has been around a fe...
# 3      If you are looking for the secret ingredient i...
# 4      Great taffy at a great price.  There was a wid...
#                              ...
# 376    Oh my gosh, is this good!  Like most people, I...
# 377    Sir Kensington's did a great job of updating t...
# 378    This is ridiculous.  The best gourmet ketchup ...
# 379    The tomatoes are the star of the classic flavo...
# 380    The spicy version of this ketchup isn't bad, b...
# Name: Text, Length: 381, dtype: object
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[126], line 2
#       1 print(example)
# ----> 2 sia.polarity_score(example)
#
# AttributeError: 'SentimentIntensityAnalyzer' object has no attribute 'polarity_score'

# %%
encoded_text=tokenizer(example,return_tensors="pt")
output=model(**encoded_text)
scores=output[0][0].detach().numpy()
scores=softmax(scores)
scores
# Out:
# array([0.0128886 , 0.06708585, 0.9200255 ], dtype=float32)

# %%
def polairty_scores_roberta(example):
    encoded_text=tokenizer(example,return_tensors='pt')
    output=model(**encoded_text)
    scores=output[0][0].detach().numpy()
    scores=softmax(scores)
    scores_dict={'roberta_neg':scores[0],
                'roberta_pos':scores[1],
           'roberta_neu':scores[2]}
    return scores_dict

# %%
## combine and shape

# %%
res={}
for i,row in tqdm(df.iterrows(),total=len(df)):
    try:
        text=row['Text']
        myid=row['Id']
        vader_results=sia.polarity_scores(text)
        vader_results_rename={}
        for key,val in vader_results.items():
            vader_results_rename[f"vader_{key}"]=val
        roberta_results=polairty_scores_roberta(text)
        both={**vader_results,**roberta_results}
        res[myid]=both
    except RuntimeError:
        print(f' Broke for {myid}')
# Out:
#   0%|          | 0/381 [00:00<?, ?it/s]
#  Broke for 83
#  Broke for 187

# %%
results_df=pd.DataFrame(res).T
results_df=results_df.reset_index().rename(columns={'index':'Id'})
results_final=results_df.merge(vaders_one,how='left')

# %%
## compare scores across models

# %%
results_final.head(1)
# Out:
#    Id  neg    neu    pos  compound  roberta_neg  roberta_pos  roberta_neu  \
# 0   1  0.0  0.695  0.305    0.9441     0.009624      0.04998     0.940395
#
#     ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 0  B001E4KFG0  A3SGXH7AUHU8GW  delmartian                     1
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...

# %%
sns.pairplot(data=results_final,vars=['neg','neu','pos','roberta_neg','roberta_neu','roberta_pos'],hue="Score")

# %%
results_final.query('Score==1').sort_values('roberta_pos',ascending=False)['Text'].values[0]
# Out:
# 'Hey, the description says 360 grams - that is roughly 13 ounces at under $4.00 per can. No way - that is the approximate price for a 100 gram can.'

# %%
## Vader
results_final.query('Score==1').sort_values('pos',ascending=False)['Text'].values[0]
# Out:
# 'So we cancelled the order.  It was cancelled without any problem.  That is a positive note...'

# %%
## Negative sentiment

# %%
results_final.query('Score==1').sort_values('roberta_neg',ascending=False)['Text'].values[0]
# Out:
# 'I so wish I would have read this review before purchasing TWO gallons of this oil for my health issues. It reeks like a chemical rubber smell. This smell is coming from the black rubber gasket in the lid. When I called to report the situation to the company, Sabrina told me I would have to pay to send them a sample to have tested by a lab. Unbelievable. Good customer service would indicate that they would pay for the product to be returned and give me a full refund, including shipping. The product is faulty. Period. I will never order anything from this company again and do not recommend it to anyone based on this horrible customer service and lack of responsibility and ownership.'

# %%
results_final.query('Score==1').sort_values('neg',ascending=False)['Text'].values[0]
# Out:
# 'A very bitter tasting coffee even when enhanced with cream and/or honey. Definately not my cup of coffee. Oh, did i say it was bitter?'

# %%
## Hugging face transformers Pipeline

# %%
from transformers import pipeline
sent_pipeline=pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
sent_pipeline('I love riding on Amtrak Train(s)')
# Out:
# [{'label': 'POSITIVE', 'score': 0.998196542263031}]

# %%
sent_pipeline('The weather is too hot and humid')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9992189407348633}]
